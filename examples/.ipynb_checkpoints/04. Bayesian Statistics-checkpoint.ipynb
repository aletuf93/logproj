# %% [markdown]
# # Bayesian Statistics
# *This notebook illustrates statistical methods for the application of Bayesian statistics*
# ***
# Alessandro Tufano 2020

# %%
import numpy as np
import pandas as pd
import pymc3 as pm
import matplotlib.pyplot as plt

# %%
#https://sciencecue.it/coronavirus-modello-matematico-evoluzione/18355/
#https://web.stanford.edu/~jhj1/teachingdocs/Jones-on-R0.pdf





#add exponential distribution to thesis
#https://www.researchgate.net/post/QWhat_is_The_main_Difference_Between_Poisson_and_Exponential_Distributions

# %% [markdown]
# ### Import data thunderstorm

# %%
df = pd.read_csv('https://github.com/ipython-books/'
                 'cookbook-2nd-data/blob/master/'
                 'Allstorms.ibtracs_wmo.v03r05.csv?'
                 'raw=true',
                 delim_whitespace=False)

# %%
cnt = df[df['Basin'] == ' NA'].groupby(
    'Season')['Serial_Num'].nunique()
# The years from 1851 to 2012.
years = cnt.index
y0, y1 = years[0], years[-1]
arr = cnt.values
# Plot the annual number of storms.
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(years, arr, '-o')
ax.set_xlim(y0, y1)
ax.set_xlabel("Year")
ax.set_ylabel("Number of storms")
# Out:
# Text(0, 0.5, 'Number of storms')

# %%
# We define our model.
with pm.Model() as model:
    # We define our three variables.
    switchpoint = pm.DiscreteUniform(
        'switchpoint', lower=y0, upper=y1)
    early_rate = pm.Exponential('early_rate', 1)
    late_rate = pm.Exponential('late_rate', 1)
    
    # The rate of the Poisson process is a piecewise
    # constant function.
    rate = pm.math.switch(switchpoint >= years,
                          early_rate, late_rate)
    # The annual number of storms per year follows
    # a Poisson distribution.
    storms = pm.Poisson('storms', rate, observed=arr)

# %%
with model:
    trace = pm.sample(1000)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [switchpoint]
# >NUTS: [late_rate, early_rate]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:03<00:00, 864.71draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace)
# Out:
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# ...

# %% [markdown]
# ### COVID-19 Italy data

# %%
# import all data
df = pd.read_csv("https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni.csv",error_bad_lines=False)
df.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione', 'lat',
#        'long', 'ricoverati_con_sintomi', 'terapia_intensiva',
#        'totale_ospedalizzati', 'isolamento_domiciliare', 'totale_positivi',
#        'variazione_totale_positivi', 'nuovi_positivi', 'dimessi_guariti',
#        'deceduti', 'totale_casi', 'tamponi', 'casi_testati', 'note_it',
#        'note_en'],
#       dtype='object')

# %%
#group by date
df_grouped = df.groupby(['data']).agg({'ricoverati_con_sintomi':['sum'],
                                       'terapia_intensiva':['sum'],
                                       'totale_ospedalizzati':['sum'],
                                       'isolamento_domiciliare':['sum'],
                                       'totale_positivi':['sum'],
                                       'variazione_totale_positivi':['sum'],
                                       'nuovi_positivi':['sum'],
                                       'dimessi_guariti':['sum'],
                                       'deceduti':['sum'],
                                       'totale_casi':['sum'],
                                       'tamponi':['sum'],
                                       'casi_testati':['sum'],
                                       
                                      
                                      }).reset_index()

# %%
#Explore data
for dataField in ['ricoverati_con_sintomi', 'terapia_intensiva',
       'totale_ospedalizzati', 'isolamento_domiciliare', 'totale_positivi',
       'variazione_totale_positivi', 'nuovi_positivi', 'dimessi_guariti',
       'deceduti', 'totale_casi', 'tamponi', 'casi_testati']:
    plt.figure()
    plt.plot(df_grouped['data'],df_grouped[dataField])
    plt.title(dataField)
    plt.xlabel

# %% [markdown]
# ### Model the total number of positive

# %%
#Define a random variable: nuovi positivi/numero tamponi

obs_positive_rate = df_grouped['nuovi_positivi'] / df_grouped['tamponi']

#remove the first 14 days with dirty data
obs_positive_rate = obs_positive_rate[14:-1]
plt.plot(obs_positive_rate)

#observed positive rate
mean_obs_positive_rate = np.round(np.mean(obs_positive_rate),4)
std_obs_positive_rate = np.round(np.std(obs_positive_rate),5)

#print statistics of the positive rate
print(f"Mean value: {mean_obs_positive_rate}")
print(f"Standard deviation: {std_obs_positive_rate}")
# Out:
# Mean value: sum    0.0113
# dtype: float64
# Standard deviation: sum    0.01057
# dtype: float64

# %%
obs_death_rate = df_grouped['deceduti'] / df_grouped['tamponi']

#remove the first 14 days with dirty data
obs_death_rate = obs_death_rate[14:-1]
plt.plot(obs_death_rate)
plt.title('Observed death rate')

#observed death rate
mean_observed_death_rate = np.round(np.mean(obs_death_rate),4)
std_observed_death_rate = np.round(np.std(obs_death_rate),5)

#assume a normal distributed death rate
mean_death_rate = 0.1
std_death_rate = 0.05
print(f"Mean value: {mean_death_rate}")
print(f"Standard deviation: {std_death_rate}")
# Out:
# Mean value: 0.1
# Standard deviation: 0.05

# %%
# We define our model.
with pm.Model() as model:
    
    #we measure the obs_positive_rate
    prior_observed_positive_rate = pm.Lognormal('observed_positive_rate',
                                          mu=mean_obs_positive_rate, 
                                          sigma = std_obs_positive_rate,
                                          observed = obs_positive_rate,
                                          )
    
    #we estimate an unknown distribution of unobserved positive
    posterior_unobserved_positive_rate_mu = pm.Uniform('unobserved_positive_rate_mu',
                                                       lower=0, 
                                                       upper=1) #unknown mu of the observed_positive_rate
    
    posterior_unobserved_positive_rate_tau = pm.Uniform('unobserved_positive_rate_tau',
                                                        lower=0, 
                                                        upper=1) #unknown tau of the observed_positive_rate
    
    posterior_unobserved_positive_rate = pm.Lognormal('unobserved_positive_rate',
                                                      mu=posterior_unobserved_positive_rate_mu, 
                                                      tau = posterior_unobserved_positive_rate_tau
                                           )
    
    
    #we assume the true death rate being normally distributed
    prior_death_rate = prior_observed_positive_rate + posterior_unobserved_positive_rate
    
    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal('Y_obs', mu=prior_death_rate, sigma=std_death_rate, observed=mean_death_rate)

# %%
with model:
    trace = pm.sample(1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [unobserved_positive_rate, unobserved_positive_rate_tau, unobserved_positive_rate_mu]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:05<00:00, 555.67draws/s]

# %%
pm.traceplot(trace)
pm.forestplot(trace)
# Out:
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning:
#
# Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning:
#
# Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning:
#
# Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning:
#
# Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning:
#
# ...

# %%
#extract results from sampling


unobserved_positive_rate_mean = 0.09
unobserved_positive_rate_std = 0


total_positive_rate_mean = unobserved_positive_rate_mean + mean_obs_positive_rate
total_positive_rate_std = unobserved_positive_rate_std + std_obs_positive_rate


print(f"Mean: {total_positive_rate_mean}")
print(f"Std: {total_positive_rate_std}")
# Out:
# Mean: sum    0.1013
# dtype: float64
# Std: sum    0.01057
# dtype: float64

# %%
#adapt nuovi positivi
D_nuovi_positivi = df_grouped['nuovi_positivi']
D_nuovi_positivi['Measured'] = D_nuovi_positivi['sum']
D_nuovi_positivi['Estimated'] = df_grouped['nuovi_positivi'] + df_grouped['nuovi_positivi']*unobserved_positive_rate_mean
D_nuovi_positivi['Estimated_1std'] = D_nuovi_positivi['Estimated'] + D_nuovi_positivi['Estimated']*unobserved_positive_rate_std
D_nuovi_positivi['Estimated_m1std'] = D_nuovi_positivi['Estimated'] - D_nuovi_positivi['Estimated']*unobserved_positive_rate_std
D_nuovi_positivi['Date'] = [i for i in range(1,len(D_nuovi_positivi)+1)]


D_nuovi_positivi = D_nuovi_positivi.loc[:, ['Date', 'Measured', 'Estimated', 'Estimated_1std', 'Estimated_m1std']]

import plotly.graph_objects as go

import pandas as pd
from datetime import datetime


fig = go.Figure(data=[
                            go.Candlestick(x=D_nuovi_positivi['Date'],
                                            open=D_nuovi_positivi['Measured'],
                                            high=D_nuovi_positivi['Estimated'],
                                            low=D_nuovi_positivi['Estimated_1std'],
                                            close=D_nuovi_positivi['Estimated_m1std'])])

fig.show()
# Out:
# C:\Users\aletu\.conda\envs\test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\aletu\.conda\envs\test\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#adapt totale positivi

D_totale_positivi = D_nuovi_positivi
D_totale_positivi['Measured'] = D_totale_positivi['Measured'].cumsum()
D_totale_positivi['Estimated'] = D_totale_positivi['Estimated'].cumsum()
D_totale_positivi['Estimated_1std'] = D_totale_positivi['Estimated_1std'].cumsum()
D_totale_positivi['Estimated_m1std'] = D_totale_positivi['Estimated_m1std'].cumsum()


D_totale_positivi = D_totale_positivi.loc[:, ['Date', 'Measured', 'Estimated', 'Estimated_1std', 'Estimated_m1std']]

import plotly.graph_objects as go

import pandas as pd
from datetime import datetime


fig = go.Figure(data=[
                            go.Candlestick(x=D_totale_positivi['Date'],
                                            open=D_totale_positivi['Measured'],
                                            high=D_totale_positivi['Estimated'],
                                            low=D_totale_positivi['Estimated_1std'],
                                            close=D_totale_positivi['Estimated_m1std'])])

fig.show()
# Out:
# <div>
#
#
#             <div id="93c9cee6-c91e-43c2-8b42-fdad6aee605d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93c9cee6-c91e-43c2-8b42-fdad6aee605d")) {
#                     Plotly.newPlot(
#                         '93c9cee6-c91e-43c2-8b42-fdad6aee605d',
# ...
